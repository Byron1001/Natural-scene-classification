# %% [markdown]
# - python please use version 3.10.x
# - if tensorflow or torch for GPU cannot run, need to reconfigure env and inform in group then

# %%
pip install -r ./req.txt
# Out:
# Collecting numpy (from -r ./req.txt (line 1))
#   Using cached numpy-2.0.1-cp310-cp310-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting pandas (from -r ./req.txt (line 2))
#   Using cached pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting cv (from -r ./req.txt (line 3))
#   Using cached cv-1.0.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting matplotlib (from -r ./req.txt (line 4))
#   Using cached matplotlib-3.9.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting seaborn (from -r ./req.txt (line 5))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting bokeh (from -r ./req.txt (line 6))
#   Using cached bokeh-3.5.1-py3-none-any.whl.metadata (12 kB)
# Collecting albumentations (from -r ./req.txt (line 7))
#   Using cached albumentations-1.4.14-py3-none-any.whl.metadata (38 kB)
# Collecting keras (from -r ./req.txt (line 8))
#   Using cached keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting tensorflow (from -r ./req.txt (line 9))
#   Using cached tensorflow-2.17.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Collecting torch (from -r ./req.txt (line 10))
#   Using cached torch-2.4.0-cp310-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting tqdm (from -r ./req.txt (line 11))
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting mrcnn (from -r ./req.txt (line 12))
#   Using cached mrcnn-0.2-py3-none-any.whl
# Collecting keras-tuner (from -r ./req.txt (line 13))
#   Using cached keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn (from -r ./req.txt (line 14))
#   Using cached scikit_learn-1.5.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas->-r ./req.txt (line 2)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->-r ./req.txt (line 2))
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r ./req.txt (line 2))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r ./req.txt (line 4))
#   Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->-r ./req.txt (line 4))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r ./req.txt (line 4))
#   Using cached fonttools-4.53.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r ./req.txt (line 4))
#   Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from matplotlib->-r ./req.txt (line 4)) (24.1)
# Collecting pillow>=8 (from matplotlib->-r ./req.txt (line 4))
#   Using cached pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r ./req.txt (line 4))
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting Jinja2>=2.9 (from bokeh->-r ./req.txt (line 6))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting PyYAML>=3.10 (from bokeh->-r ./req.txt (line 6))
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.10/site-packages (from bokeh->-r ./req.txt (line 6)) (6.4.1)
# Collecting xyzservices>=2021.09.1 (from bokeh->-r ./req.txt (line 6))
#   Using cached xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting scipy>=1.10.0 (from albumentations->-r ./req.txt (line 7))
#   Using cached scipy-1.14.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting scikit-image>=0.21.0 (from albumentations->-r ./req.txt (line 7))
#   Using cached scikit_image-0.24.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in ./.venv/lib/python3.10/site-packages (from albumentations->-r ./req.txt (line 7)) (4.12.2)
# Collecting pydantic>=2.7.0 (from albumentations->-r ./req.txt (line 7))
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting albucore>=0.0.13 (from albumentations->-r ./req.txt (line 7))
#   Using cached albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# Collecting eval-type-backport (from albumentations->-r ./req.txt (line 7))
#   Using cached eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations->-r ./req.txt (line 7))
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting absl-py (from keras->-r ./req.txt (line 8))
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras->-r ./req.txt (line 8))
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras->-r ./req.txt (line 8))
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting h5py (from keras->-r ./req.txt (line 8))
#   Using cached h5py-3.11.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting optree (from keras->-r ./req.txt (line 8))
#   Using cached optree-0.12.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (47 kB)
# Collecting ml-dtypes (from keras->-r ./req.txt (line 8))
#   Using cached ml_dtypes-0.4.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting astunparse>=1.6.0 (from tensorflow->-r ./req.txt (line 9))
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow->-r ./req.txt (line 9))
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow->-r ./req.txt (line 9))
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow->-r ./req.txt (line 9))
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow->-r ./req.txt (line 9))
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow->-r ./req.txt (line 9))
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow->-r ./req.txt (line 9))
#   Using cached protobuf-4.25.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow->-r ./req.txt (line 9))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.10/site-packages (from tensorflow->-r ./req.txt (line 9)) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorflow->-r ./req.txt (line 9)) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow->-r ./req.txt (line 9))
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting wrapt>=1.11.0 (from tensorflow->-r ./req.txt (line 9))
#   Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow->-r ./req.txt (line 9))
#   Downloading grpcio-1.65.5-cp310-cp310-macosx_12_0_universal2.whl.metadata (3.3 kB)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow->-r ./req.txt (line 9))
#   Using cached tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow->-r ./req.txt (line 9))
#   Using cached tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting numpy (from -r ./req.txt (line 1))
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting filelock (from torch->-r ./req.txt (line 10))
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy (from torch->-r ./req.txt (line 10))
#   Using cached sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch->-r ./req.txt (line 10))
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting fsspec (from torch->-r ./req.txt (line 10))
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting kt-legacy (from keras-tuner->-r ./req.txt (line 13))
#   Using cached kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Collecting joblib>=1.2.0 (from scikit-learn->-r ./req.txt (line 14))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r ./req.txt (line 14))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting tomli>=2.0.1 (from albucore>=0.0.13->albumentations->-r ./req.txt (line 7))
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow->-r ./req.txt (line 9))
#   Using cached wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.9->bokeh->-r ./req.txt (line 6))
#   Using cached MarkupSafe-2.1.5-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.7.0->albumentations->-r ./req.txt (line 7))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic>=2.7.0->albumentations->-r ./req.txt (line 7))
#   Using cached pydantic_core-2.20.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow->-r ./req.txt (line 9))
#   Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow->-r ./req.txt (line 9))
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow->-r ./req.txt (line 9))
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow->-r ./req.txt (line 9))
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting imageio>=2.33 (from scikit-image>=0.21.0->albumentations->-r ./req.txt (line 7))
#   Using cached imageio-2.35.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.21.0->albumentations->-r ./req.txt (line 7))
#   Using cached tifffile-2024.8.10-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.21.0->albumentations->-r ./req.txt (line 7))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow->-r ./req.txt (line 9))
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow->-r ./req.txt (line 9))
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow->-r ./req.txt (line 9))
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras->-r ./req.txt (line 8))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich->keras->-r ./req.txt (line 8)) (2.18.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch->-r ./req.txt (line 10))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras->-r ./req.txt (line 8))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
# Using cached cv-1.0.0-py3-none-any.whl (7.3 kB)
# Using cached matplotlib-3.9.2-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached bokeh-3.5.1-py3-none-any.whl (6.8 MB)
# Using cached albumentations-1.4.14-py3-none-any.whl (177 kB)
# Using cached keras-3.5.0-py3-none-any.whl (1.1 MB)
# Using cached tensorflow-2.17.0-cp310-cp310-macosx_12_0_arm64.whl (236.1 MB)
# Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Using cached torch-2.4.0-cp310-none-macosx_11_0_arm64.whl (62.1 MB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached keras_tuner-1.4.7-py3-none-any.whl (129 kB)
# Using cached scikit_learn-1.5.1-cp310-cp310-macosx_12_0_arm64.whl (11.0 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached albucore-0.0.13-py3-none-any.whl (8.5 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (244 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.53.1-cp310-cp310-macosx_11_0_arm64.whl (2.2 MB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.65.5-cp310-cp310-macosx_12_0_universal2.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 21.0 MB/s eta 0:00:00 0:00:01
# Using cached h5py-3.11.0-cp310-cp310-macosx_11_0_arm64.whl (2.9 MB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl (66 kB)
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Using cached ml_dtypes-0.4.0-cp310-cp310-macosx_10_9_universal2.whl (390 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
# Using cached protobuf-4.25.4-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached scikit_image-0.24.0-cp310-cp310-macosx_12_0_arm64.whl (13.4 MB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached scipy-1.14.0-cp310-cp310-macosx_14_0_arm64.whl (23.1 MB)
# Using cached tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
# Using cached tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl (3.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Using cached xyzservices-2024.6.0-py3-none-any.whl (83 kB)
# Using cached eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Using cached namex-0.0.8-py3-none-any.whl (5.8 kB)
# Using cached optree-0.12.1-cp310-cp310-macosx_11_0_arm64.whl (282 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached imageio-2.35.0-py3-none-any.whl (315 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-macosx_10_9_universal2.whl (18 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached tifffile-2024.8.10-py3-none-any.whl (225 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached wheel-0.44.0-py3-none-any.whl (67 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, namex, mrcnn, mpmath, libclang, kt-legacy, flatbuffers, xyzservices, wrapt, wheel, urllib3, tzdata, tqdm, tomli, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, sympy, PyYAML, pyparsing, pydantic-core, protobuf, pillow, optree, numpy, networkx, mdurl, MarkupSafe, markdown, lazy-loader, kiwisolver, joblib, idna, grpcio, google-pasta, gast, fsspec, fonttools, filelock, eval-type-backport, cycler, cv, charset-normalizer, certifi, annotated-types, absl-py, werkzeug, tifffile, scipy, requests, pydantic, pandas, opt-einsum, opencv-python-headless, ml-dtypes, markdown-it-py, Jinja2, imageio, h5py, contourpy, astunparse, torch, tensorboard, scikit-learn, scikit-image, rich, matplotlib, bokeh, albucore, seaborn, keras, albumentations, tensorflow, keras-tuner
# Successfully installed Jinja2-3.1.4 MarkupSafe-2.1.5 PyYAML-6.0.2 absl-py-2.1.0 albucore-0.0.13 albumentations-1.4.14 annotated-types-0.7.0 astunparse-1.6.3 bokeh-3.5.1 certifi-2024.7.4 charset-normalizer-3.3.2 contourpy-1.2.1 cv-1.0.0 cycler-0.12.1 eval-type-backport-0.2.0 filelock-3.15.4 flatbuffers-24.3.25 fonttools-4.53.1 fsspec-2024.6.1 gast-0.6.0 google-pasta-0.2.0 grpcio-1.65.5 h5py-3.11.0 idna-3.7 imageio-2.35.0 joblib-1.4.2 keras-3.5.0 keras-tuner-1.4.7 kiwisolver-1.4.5 kt-legacy-1.0.5 lazy-loader-0.4 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 matplotlib-3.9.2 mdurl-0.1.2 ml-dtypes-0.4.0 mpmath-1.3.0 mrcnn-0.2 namex-0.0.8 networkx-3.3 numpy-1.26.4 opencv-python-headless-4.10.0.84 opt-einsum-3.3.0 optree-0.12.1 pandas-2.2.2 pillow-10.4.0 protobuf-4.25.4 pydantic-2.8.2 pydantic-core-2.20.1 pyparsing-3.1.2 pytz-2024.1 requests-2.32.3 rich-13.7.1 scikit-image-0.24.0 scikit-learn-1.5.1 scipy-1.14.0 seaborn-0.13.2 sympy-1.13.2 tensorboard-2.17.1 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.4.0 threadpoolctl-3.5.0 tifffile-2024.8.10 tomli-2.0.1 torch-2.4.0 tqdm-4.66.5 tzdata-2024.1 urllib3-2.2.2 werkzeug-3.0.3 wheel-0.44.0 wrapt-1.16.0 xyzservices-2024.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch-vision
# Out:
# Collecting torch-vision
#   Using cached torch_vision-0.1.6.dev0-py2.py3-none-any.whl.metadata (9.8 kB)
# Using cached torch_vision-0.1.6.dev0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: torch-vision
# Successfully installed torch-vision-0.1.6.dev0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchaudio
# Out:
# Collecting torchaudio
#   Using cached torchaudio-2.4.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: torch==2.4.0 in ./.venv/lib/python3.10/site-packages (from torchaudio) (2.4.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from torch==2.4.0->torchaudio) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.10/site-packages (from torch==2.4.0->torchaudio) (4.12.2)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch==2.4.0->torchaudio) (1.13.2)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch==2.4.0->torchaudio) (3.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch==2.4.0->torchaudio) (3.1.4)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.10/site-packages (from torch==2.4.0->torchaudio) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch==2.4.0->torchaudio) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy->torch==2.4.0->torchaudio) (1.3.0)
# Using cached torchaudio-2.4.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade bokeh
# Out:
# Requirement already satisfied: bokeh in ./.venv/lib/python3.10/site-packages (3.5.1)
# Requirement already satisfied: Jinja2>=2.9 in ./.venv/lib/python3.10/site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in ./.venv/lib/python3.10/site-packages (from bokeh) (1.2.1)
# Requirement already satisfied: numpy>=1.16 in ./.venv/lib/python3.10/site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in ./.venv/lib/python3.10/site-packages (from bokeh) (24.1)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.10/site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in ./.venv/lib/python3.10/site-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in ./.venv/lib/python3.10/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.10/site-packages (from bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./.venv/lib/python3.10/site-packages (from bokeh) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mrcnn
# Out:
# Requirement already satisfied: mrcnn in ./.venv/lib/python3.10/site-packages (0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# List all available devices
print("Available devices:")
devices = tf.config.list_physical_devices()
for device in devices:
    print(device)

# Check for GPU specifically (Metal for M1 Macs)
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print("GPU is available: ", gpu_devices)
    for gpu in gpu_devices:
        print("Name:", gpu.name, "  Type:", gpu.device_type)
else:
    print("GPU not available.")
# Out:
# Available devices:
# PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
# GPU not available.

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')
